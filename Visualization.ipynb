# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd

G = nx.Graph()
graph = nx.read_edgelist("C:\\Users\\18b-052-cs\\Desktop\\12.txt")
print(nx.info(edges))


pos = nx.spring_layout(graph,k=0.30,iterations=50)
catlist=["IMF","WorldBank","AsianInfrastructureInvestmentBank","AsianDevelopmentBank"]
color_map=[]
for node in graph:
    if node in catlist:
        color_map.append("blue")
    else: 
        color_map.append("green")
nx.draw_networkx(graph,pos,node_size=20,font_size=9,node_color=color_map)

nx.draw_networkx(graph,pos=pos)
fig = plt.gcf()
fig.set_size_inches((10,10))
plt.show()
# Out:
# Name:
# Type: Graph
# Number of nodes: 77
# Number of edges: 100
# Average degree:   2.5974
